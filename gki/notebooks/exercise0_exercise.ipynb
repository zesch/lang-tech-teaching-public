# %%
# style the notebook
from IPython.core.display import HTML

HTML("<style>" + open("style.css").read() + "</style>")
# Out:
# <style>/* Style des gesamten Dokuments */
# #notebook-container {
# 	font-family: "NimbusMonL-ReguObli";
# 	font-size: 120%
# }
#
# /* Style fÃ¼r die Ãœberschrift: Zentriert diese und stellt sie fett dar. */
# .headline {
# 	text-align: center;
# 	font-weight: bold;
# 	font-size: 185.7%
# }
#
# /* Style fÃ¼r die Aufgabenbeschreibung. Z.B.: "Ãœbung zum Thema..." */
# .description {
# 	text-align: center;
# 	font-size: 145.7%
# }
#
# /* Hebt das Abgabedatum fett und kursiv hervor */
# #submission {
# 	font-weight: bold;
# }
#
# /* Style fÃ¼r das eigentliche Thema. Z.B.: "Intelligenz" */
# #topic {
# 	font-style: italic;
# }
#
# .task_description {
#
# }
#
# /* Hebt die Aufgabennummerierung fett hervor. */
# .task {
# 	font-style: normal;
# 	font-weight: bold;
# }
#
# .points {
# 	font-style: italic;
# }
#
# ol.lower_roman {
#     list-style-type: lower-roman;
# }
#
# ol.characters {
#     list-style-type: lower-alpha;
# }
#
# /* Style einer Code-Cell */
# .CodeMirror-code {
# ...

# %% [markdown]
# <div class="headline">
# Grundlagen künstlicher Intelligenz
# <br><br>
# Sommersemester 2019
# </div>
# <br>
# <div class="description">
#     Übung zum Thema <i id="topic">"Jupyter Notebook"</i>
#     <br><br>
#     Deadline Abgabe: <i #id="submission">Freitag, 20.4.2020 (23:55 Uhr)</i>
# </div>

# %% [markdown]
# ## Präsenzübung

# %% [markdown]
# <div class="task_description">
#     <i class="task">Task 0.1:</i>
#
# Installieren Sie Jupyter Notebook mithilfe des Pythons Paketmanager Pip. Wenn Sie diese Aufgabenbeschreibung erreicht haben, haben Sie diese Aufgabe wahrscheinlich bereits erledigt.
#
# *Install Jupyter Notebook using python's package-management system Pip. If you're reading this, you have probably already successfully completed this task.*
# </div>

# %% [markdown]
# <div class="task_description">
#     <i class="task">Task 0.2:</i>
#
# Machen Sie sich mit den beiden verfügbaren Zelltypen vertraut:
# * Code-Zellen können dafür genutzt werden, um Python-Code zu schreiben und auszuführen.
# * Markdown-Zellen können dafür verwendet werden, um Text zu schreiben und durch Markdown und / oder HTML schön zu formatieren.
#
# Durch einen Click in eine Zelle und Betätigung der Tastenkombination Strg+Eingabe kann der Code einer Code-Zelle ausgeführt werden oder der Text einer Markdown-Zelle im angegebenen Format angezeigt werden. Durch Doppelklick auf eine Markdown-Zelle können Sie sich den nicht formatierten Text anschauen.
#
# Experimentieren Sie mit den Zelltypen herum. Jeweils ein Beispiel für eine Code-Zelle und eine Markdown-Zelle befinden sich unterhalb dieser Zelle.
#
# *Familiarize yourself with the two available cell types:
# * Code cells can be used to write and execute Python code.
# * Markdown cells can be used to write text and nicely format it using Markdown and/or HTML.
#
# *By clicking in a cell and pressing the key combination Ctrl+Enter, the code of a code cell can be executed or the text of a markdown cell can be displayed in the specified format. By double-clicking on a markdown cell, you can view the unformatted text.*
#
# *Experiment with the cell types. One example each of a code cell and a markdown cell is located below this cell.*
#
# </div>

# %%
# Example for a code cell
print("Hello World!")

# %% [markdown]
# <div style="background-color: #DDDDDD;">
#
# ### Markdown Cell
#
# #### This is a headline. The more hashtags you use the smaller it becomes.
#
# * List entry 1
# * List entry 2
#
# Use one empty line for a line break!
#
# *italics*
#
# **bold**
#
# ~~strikethrough~~
#
# 1. ordered list entry 1
#   1. ordered sublist entry 1
#   2. ordered sublist entry 2
# 2. ordered list entry 2
#   * unordered sublist entry 1
#   * unordered sublist entry 2
#
# Python-Code:
# ```Python
# x = 100
# print(x)
# ```
#
# A table:
#
# | Name          | Age           | Gender|
# | ------------- |:-------------:| -----:|
# | Alexander     | 24            |  ♂    |
# | Jonathan      | 30            |  ♂    |
# | Elizabeth     | 21            |  ♀    |
#
# Further reading: https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
#
# </div>

# %% [markdown]
# <div class="task_description">
#     <i class="task">Task 0.3:</i>
#
# Neue Zellen können über die Option Insert -> Insert Cell Above / Below über und unter dieser Zelle eingefügt werden. Der Zelltyp kann über das Dropdown-Menü verändert werden. Standardmäßig ist eine Zelle nach Erstellung eine Code-Zelle.
#
# Zum Löschen einer Zelle müssen Sie nur die entsprechende Zelle auswählen und über Edit -> Delete Cells entfernen.
#
# Erstellen Sie jeweils eine neue Code- und Markdown-Zelle.
#
# *By using the Insert -> Insert Cell Above / Below option new cells can be inserted  above and below this cell. The cell type can be changed using the drop-down menu. By default a cell is a code cell after creation.*
#
# *To delete a cell, simply select the corresponding cell and remove it via Edit -> Delete Cells.*
#
# *Create a new code and markdown cell.*
# </div>

# %% [markdown]
# <div class="task_description">
#     <i class="task">Task 0.4:</i>
#
# Auf Variablen / Funktionen / importierte Bibliotheken einer Code-Zelle können in allen Code-Zellen danach zugegriffen werden. Der Output einer Code-Zelle kann über Cell -> Current Outputs -> Clear gelöscht werden. Wenn Sie den Output aller Zellen löschen wollen, können sie das über Cell -> All Output -> Clear tun.
#
# Probieren Sie folgendes an den beiden Code-Zellen Cell 1 und Cell 2 aus:
# 1. Führen Sie Cell 1 und Cell 2 nacheinander aus.
# 2. Ändern Sie den Wert von "variable" auf 16 und führen Sie danach Cell2 aus.
# 3. Ändern Sie den Wert von "variable" auf 17 und führen sie Cell 1 und Cell 2 nacheinander aus.
#
# Was sollte ausgegeben werden? Was wird tatsächlich ausgegeben?
#
# *Variables / functions / imported libraries of a code cell can be accessed in all subsequent code cells. The output of a code cell can be deleted via Cell -> Current Outputs -> Clear. If you want to delete the output of all cells, you can do this via Cell -> All Output -> Clear.*
#
# *Try the following on the two code cells Cell 1 and Cell 2:*
# 1. *Execute Cell 1 and Cell 2 one after the other.*
# 2. *Change the value of "variable" to 16 and then execute Cell 2.*
# 3. *Change the value of "variable" to 17 and execute Cell 1 and Cell 2 one after the other.*
# </div>

# %%
#Cell 1
variable = 15

# %%
# Cell 2
print(variable)
